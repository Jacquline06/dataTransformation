# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Orange_Telecom_Churn_Data.csv')

# %%
df
# Out:
#      state  account_length  area_code phone_number intl_plan voice_mail_plan  \
# 0       KS             128        415     382-4657        no             yes
# 1       OH             107        415     371-7191        no             yes
# 2       NJ             137        415     358-1921        no              no
# 3       OH              84        408     375-9999       yes              no
# 4       OK              75        415     330-6626       yes              no
# ...    ...             ...        ...          ...       ...             ...
# 4995    HI              50        408     365-8751        no             yes
# 4996    WV             152        415     334-9736        no              no
# 4997    DC              61        415     333-6861        no              no
# 4998    DC             109        510     394-2206        no              no
# 4999    VT              86        415     373-8058        no             yes
#
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
sns.distplot(df["account_length"],fit=norm)
# Out:
# <ipython-input-5-d0fe7cd321dc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["account_length"],fit=norm)
# <Axes: xlabel='account_length', ylabel='Density'>

# %%
df = df.drop('state', axis=1)

# %%
df = df.drop('phone_number', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-0582ec61c0bf> in <cell line: 1>()
# ----> 1 df = df.drop('phone_number', axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5342                 weight  1.0     0.8
#    5343         """
# -> 5344         return super().drop(
#    5345             labels=labels,
#    5346             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709         for axis, labels in axes.items():
#    4710             if labels is not None:
# -> 4711                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4712
#    4713         if inplace:
#
# ...

# %%
df = df.drop('intl_plan', axis=1)

# %%
df = df.drop('voice_mail_plan', axis=1)

# %%
df = df.drop('churned', axis=1)

# %%
df
# Out:
#       account_length  area_code  number_vmail_messages  total_day_minutes  \
# 0                128        415                     25              265.1
# 1                107        415                     26              161.6
# 2                137        415                      0              243.4
# 3                 84        408                      0              299.4
# 4                 75        415                      0              166.7
# ...              ...        ...                    ...                ...
# 4995              50        408                     40              235.7
# 4996             152        415                      0              184.2
# 4997              61        415                      0              140.6
# 4998             109        510                      0              188.8
# 4999              86        415                     34              129.4
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# ...

# %%
df["area_code_new"] = np.log(df["area_code"])

# %%
df["number_vmail_messages_new"] = np.log(df["number_vmail_messages"])                                           # number_vmail_messages
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1010: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#       account_length  area_code  number_vmail_messages  total_day_minutes  \
# 0                128        415                     25              265.1
# 1                107        415                     26              161.6
# 2                137        415                      0              243.4
# 3                 84        408                      0              299.4
# 4                 75        415                      0              166.7
# ...              ...        ...                    ...                ...
# 4995              50        408                     40              235.7
# 4996             152        415                      0              184.2
# 4997              61        415                      0              140.6
# ...

# %%
for i in df.columns[:-1]:
  print(i, df[i].skew())
  sns.distplot(df[i],fit=norm)
  plt.show()
# Out:
# account_length 0.1092911238427682
# <ipython-input-31-56b5fdb3d6f1>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# area_code 1.1437899623197059
# <ipython-input-31-56b5fdb3d6f1>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[i],fit=norm)
# ...

# %%
for i in df.columns:
  print(i,df[i].skew())
# Out:
# account_length 0.1092911238427682
# area_code 1.1437899623197059
# number_vmail_messages 1.3504931974826235
# total_day_minutes -0.011730827167578775
# total_day_calls -0.08489096367281956
# total_day_charge -0.011729007073761826
# total_eve_minutes -0.011017694585014734
# total_eve_calls -0.020175203277375608
# total_eve_charge -0.010990328362308517
# total_night_minutes 0.01932491656404777
# total_night_calls 0.0021328427438912423
# total_night_charge 0.019286744338659848
# total_intl_minutes -0.20996629286844293
# total_intl_calls 1.360692479402265
# total_intl_charge -0.21028611467847302
# number_customer_service_calls 1.042462330340439
# area_code_new 1.1397824540463364
# number_vmail_messages_new nan
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py:1248: RuntimeWarning: invalid value encountered in subtract
#   adjusted = values - mean
